# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
path = '/Users/sena/grad_school/Research/netmet/data/'

# %%
input_data = pd.read_csv(path+'input_data.csv')

# %%
#drop the unnamed column
input_data = input_data.drop(columns='Unnamed: 0')

# %%
input_data
# Out:
#          Jet_0_eta  Jet_0_phi  Jet_0_pt  Jet_1_eta  Jet_1_phi  Jet_1_pt  \
# 0         1.609619   2.218262      65.0   1.087402   0.043503      25.5
# 1         3.741211   2.044434      56.0   2.262207   1.435547      41.5
# 2         3.219238   2.305664      58.0   2.392578   0.478516      34.0
# 3        -0.217499   3.001465      27.0  -1.435547  -0.671631      23.0
# 4         1.609619   2.479492      40.5   1.087402  -0.845703      27.0
# ...            ...        ...       ...        ...        ...       ...
# 3145852   2.740723   2.218262      34.5   0.217499   0.478516      24.0
# 3145853   0.304504   2.740723      75.0  -2.000977  -0.758667      17.0
# 3145854  -0.043503  -1.106689     233.0  -3.219238  -2.672852      21.5
# 3145855   1.261475   2.392578      97.0   0.652466   0.652466      39.0
# 3145856   1.696533   1.696533      24.5   1.174561   0.565552      22.5
#
#          Jet_2_eta  Jet_2_phi  Jet_2_pt  Jet_3_eta  Jet_3_phi  Jet_3_pt  \
# ...

# %%
puppiMETnoMU = pd.read_csv(path+'puppiMETnoMU.csv')

# %%
puppiMETnoMU
# Out:
#          PuppiMET_pt
# 0          48.759895
# 1         104.013786
# 2          59.436253
# 3          10.841270
# 4          62.679337
# ...              ...
# 3145852    57.547897
# 3145853    80.715759
# 3145854   244.846283
# 3145855    85.398529
# 3145856    15.334833
#
# [3145857 rows x 1 columns]

# %%
full_data = pd.concat([input_data, puppiMETnoMU], axis=1)

# %%
full_data
# Out:
#          Jet_0_eta  Jet_0_phi  Jet_0_pt  Jet_1_eta  Jet_1_phi  Jet_1_pt  \
# 0         1.609619   2.218262      65.0   1.087402   0.043503      25.5
# 1         3.741211   2.044434      56.0   2.262207   1.435547      41.5
# 2         3.219238   2.305664      58.0   2.392578   0.478516      34.0
# 3        -0.217499   3.001465      27.0  -1.435547  -0.671631      23.0
# 4         1.609619   2.479492      40.5   1.087402  -0.845703      27.0
# ...            ...        ...       ...        ...        ...       ...
# 3145852   2.740723   2.218262      34.5   0.217499   0.478516      24.0
# 3145853   0.304504   2.740723      75.0  -2.000977  -0.758667      17.0
# 3145854  -0.043503  -1.106689     233.0  -3.219238  -2.672852      21.5
# 3145855   1.261475   2.392578      97.0   0.652466   0.652466      39.0
# 3145856   1.696533   1.696533      24.5   1.174561   0.565552      22.5
#
#          Jet_2_eta  Jet_2_phi  Jet_2_pt  Jet_3_eta  Jet_3_phi  Jet_3_pt  \
# ...

# %%
#inspect the data 
full_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3145857 entries, 0 to 3145856
# Data columns (total 15 columns):
#  #   Column       Dtype
# ---  ------       -----
#  0   Jet_0_eta    float64
#  1   Jet_0_phi    float64
#  2   Jet_0_pt     float64
#  3   Jet_1_eta    float64
#  4   Jet_1_phi    float64
#  5   Jet_1_pt     float64
#  6   Jet_2_eta    float64
#  7   Jet_2_phi    float64
#  8   Jet_2_pt     float64
#  9   Jet_3_eta    float64
#  10  Jet_3_phi    float64
#  11  Jet_3_pt     float64
#  12  methf_0_pt   float64
#  13  ntt_0_pt     float64
#  14  PuppiMET_pt  float64
# dtypes: float64(15)
# memory usage: 360.0 MB

# %%
#plot every column vs PuppiMET_Pt column
for column in full_data.columns:
    plt.scatter(full_data[column], full_data['PuppiMET_pt'])
    plt.ylabel('PuppiMET_Pt')
    plt.xlabel(column)
    plt.title(column + ' vs PuppiMET_Pt')
    plt.show()

# %% [markdown]
# ### Seems like something weird is going on with the jet pt's and puppimet. Let's inspect this further

# %%
jet_0_pt = pd.concat([full_data['Jet_0_pt'], full_data['PuppiMET_pt']], axis=1)

# %%
jet_0_pt
# Out:
#          Jet_0_pt  PuppiMET_pt
# 0            65.0    48.759895
# 1            56.0   104.013786
# 2            58.0    59.436253
# 3            27.0    10.841270
# 4            40.5    62.679337
# ...           ...          ...
# 3145852      34.5    57.547897
# 3145853      75.0    80.715759
# 3145854     233.0   244.846283
# 3145855      97.0    85.398529
# 3145856      24.5    15.334833
#
# [3145857 rows x 2 columns]

# %%
#count the number of rows with value bigger than 1000 and find how many different values are there
jet_0_pt[jet_0_pt['Jet_0_pt'] > 1000].nunique()
# Out:
# Jet_0_pt           1
# PuppiMET_pt    12345
# dtype: int64

# %%
#plot these rows with value bigger than 1000 versus PuppiMET_pt
plt.scatter(jet_0_pt[jet_0_pt['Jet_0_pt'] > 1000]['Jet_0_pt'], jet_0_pt[jet_0_pt['Jet_0_pt'] > 1000]['PuppiMET_pt'])
#zoom in on x axis
plt.xlim(1022.5, 1025)
# Out:
# (1022.5, 1025.0)

# %%
jet_0_pt[jet_0_pt['Jet_0_pt'] > 1000]
# Out:
#          Jet_0_pt  PuppiMET_pt
# 91         1023.5   170.886185
# 322        1023.5   190.832321
# 417        1023.5   165.050064
# 763        1023.5   350.168121
# 779        1023.5   175.014984
# ...           ...          ...
# 3144497    1023.5   128.873825
# 3144709    1023.5   146.691971
# 3144711    1023.5    55.491280
# 3145672    1023.5    20.746025
# 3145759    1023.5   246.799225
#
# [12350 rows x 2 columns]

# %%
12350/3145759*100
# Out:
# 0.39259205806929265

# %%
#plot the columns with jet_0_pt  vs jet_0_phi
plt.scatter(full_data['Jet_0_phi'],full_data['Jet_0_pt'])
plt.xlabel('Jet_0_phi')
plt.ylabel('Jet_0_pt')
# Out:
# Text(0, 0.5, 'Jet_0_pt')

# %%
#clean the full_data to get rid of jets with pt > 1000
clean_data = full_data[full_data['Jet_0_pt'] < 1000]
clean_data = clean_data[clean_data['Jet_1_pt'] < 1000]
clean_data = clean_data[clean_data['Jet_2_pt'] < 1000]
clean_data = clean_data[clean_data['Jet_3_pt'] < 1000]

# %%
clean_data
# Out:
#          Jet_0_eta  Jet_0_phi  Jet_0_pt  Jet_1_eta  Jet_1_phi  Jet_1_pt  \
# 0         1.609619   2.218262      65.0   1.087402   0.043503      25.5
# 1         3.741211   2.044434      56.0   2.262207   1.435547      41.5
# 2         3.219238   2.305664      58.0   2.392578   0.478516      34.0
# 3        -0.217499   3.001465      27.0  -1.435547  -0.671631      23.0
# 4         1.609619   2.479492      40.5   1.087402  -0.845703      27.0
# ...            ...        ...       ...        ...        ...       ...
# 3145852   2.740723   2.218262      34.5   0.217499   0.478516      24.0
# 3145853   0.304504   2.740723      75.0  -2.000977  -0.758667      17.0
# 3145854  -0.043503  -1.106689     233.0  -3.219238  -2.672852      21.5
# 3145855   1.261475   2.392578      97.0   0.652466   0.652466      39.0
# 3145856   1.696533   1.696533      24.5   1.174561   0.565552      22.5
#
#          Jet_2_eta  Jet_2_phi  Jet_2_pt  Jet_3_eta  Jet_3_phi  Jet_3_pt  \
# ...

# %%
full_data
# Out:
#          Jet_0_eta  Jet_0_phi  Jet_0_pt  Jet_1_eta  Jet_1_phi  Jet_1_pt  \
# 0         1.609619   2.218262      65.0   1.087402   0.043503      25.5
# 1         3.741211   2.044434      56.0   2.262207   1.435547      41.5
# 2         3.219238   2.305664      58.0   2.392578   0.478516      34.0
# 3        -0.217499   3.001465      27.0  -1.435547  -0.671631      23.0
# 4         1.609619   2.479492      40.5   1.087402  -0.845703      27.0
# ...            ...        ...       ...        ...        ...       ...
# 3145852   2.740723   2.218262      34.5   0.217499   0.478516      24.0
# 3145853   0.304504   2.740723      75.0  -2.000977  -0.758667      17.0
# 3145854  -0.043503  -1.106689     233.0  -3.219238  -2.672852      21.5
# 3145855   1.261475   2.392578      97.0   0.652466   0.652466      39.0
# 3145856   1.696533   1.696533      24.5   1.174561   0.565552      22.5
#
#          Jet_2_eta  Jet_2_phi  Jet_2_pt  Jet_3_eta  Jet_3_phi  Jet_3_pt  \
# ...

# %%
len(clean_data)/len(full_data)*100
# Out:
# 99.6074201719913

# %%
#inspect the zeros in eta values
len(clean_data[clean_data['Jet_0_eta'] == 0])/len(clean_data)*100
# Out:
# 9.917322667541512

# %% [markdown]
# ### Now inspect why there is an empty region in the plots with eta on the x axis

# %%
import matplotlib.pyplot as plt

# Create a 1x3 grid of subplots
fig, axs = plt.subplots(1, 4, figsize=(15, 5))

# Plot for eta range -4 to -2
axs[0].scatter(clean_data[(clean_data['Jet_0_eta'] > -4) & (clean_data['Jet_0_eta'] < -2)]['Jet_0_eta'],
               clean_data[(clean_data['Jet_0_eta'] > -4) & (clean_data['Jet_0_eta'] < -2)]['Jet_0_pt'])
axs[0].set_title('Jet_0_eta -4 to -2 vs Jet_0_pt')
axs[0].set_xlabel('Jet_0_eta')
axs[0].set_ylabel('Jet_0_pt')

# Plot for eta range -2 to 2
axs[1].scatter(clean_data[(clean_data['Jet_0_eta'] > -2) & (clean_data['Jet_0_eta'] < 0)]['Jet_0_eta'],
               clean_data[(clean_data['Jet_0_eta'] > -2) & (clean_data['Jet_0_eta'] < 0)]['Jet_0_pt'])
axs[1].set_title('Jet_0_eta -2 to 2 vs Jet_0_pt')
axs[1].set_xlabel('Jet_0_eta')
axs[1].set_ylabel('Jet_0_pt')

# Plot for eta range 2 to 4
axs[2].scatter(clean_data[(clean_data['Jet_0_eta'] > 0) & (clean_data['Jet_0_eta'] < 2)]['Jet_0_eta'],
               clean_data[(clean_data['Jet_0_eta'] > 0) & (clean_data['Jet_0_eta'] < 2)]['Jet_0_pt'])
axs[2].set_title('Jet_0_eta 2 to 4 vs Jet_0_pt')
axs[2].set_xlabel('Jet_0_eta')
axs[2].set_ylabel('Jet_0_pt')

# Plot for eta range 2 to 4 
axs[3].scatter(clean_data[(clean_data['Jet_0_eta'] > 2) & (clean_data['Jet_0_eta'] < 4)]['Jet_0_eta'],
               clean_data[(clean_data['Jet_0_eta'] > 2) & (clean_data['Jet_0_eta'] < 4)]['Jet_0_pt'])
axs[3].set_title('Jet_0_eta 2 to 4 vs Jet_0_pt')
axs[3].set_xlabel('Jet_0_eta')
axs[3].set_ylabel('Jet_0_pt')


# Adjust layout for clarity
plt.tight_layout()
plt.show()

# %%
clean_data[(clean_data['Jet_0_eta'] >= -4) & (clean_data['Jet_0_eta'] <= -2)]['Jet_0_eta'].nunique()
# Out:
# 12

# %%
clean_data[(clean_data['Jet_0_eta'] >= -2) & (clean_data['Jet_0_eta'] <= 0)]['Jet_0_eta'].nunique()
# Out:
# 23

# %%
clean_data[(clean_data['Jet_0_eta'] >= 0) & (clean_data['Jet_0_eta'] <= 2)]['Jet_0_eta'].nunique()
# Out:
# 23

# %%
clean_data[(clean_data['Jet_0_eta'] >= 2) & (clean_data['Jet_0_eta'] <=4)]['Jet_0_eta'].nunique()
# Out:
# 12

# %%
import matplotlib.pyplot as plt

# Create a 1x3 grid of subplots
fig, axs = plt.subplots(1, 6, figsize=(15, 5))

# Plot for eta range -4 to -2
axs[0].scatter(clean_data[(clean_data['Jet_0_eta'] > -4) & (clean_data['Jet_0_eta'] < -2)]['Jet_0_eta'],
               clean_data[(clean_data['Jet_0_eta'] > -4) & (clean_data['Jet_0_eta'] < -2)]['PuppiMET_pt'])
axs[0].set_title('Jet_0_eta -4 to -2 vs PuppiMET_pt')
axs[0].set_xlabel('Jet_0_eta')
axs[0].set_ylabel('PuppiMET_pt')

# Plot for eta range -2 to 2
axs[1].scatter(clean_data[(clean_data['Jet_0_eta'] > -2) & (clean_data['Jet_0_eta'] < 0)]['Jet_0_eta'],
               clean_data[(clean_data['Jet_0_eta'] > -2) & (clean_data['Jet_0_eta'] < 0)]['PuppiMET_pt'])
axs[1].set_title('Jet_0_eta -2 to 2 vs PuppiMET_pt')
axs[1].set_xlabel('Jet_0_eta')
axs[1].set_ylabel('PuppiMET_pt')

# Plot for eta range 2 to 4
axs[2].scatter(clean_data[(clean_data['Jet_0_eta'] > 0) & (clean_data['Jet_0_eta'] < 2)]['Jet_0_eta'],
               clean_data[(clean_data['Jet_0_eta'] > 0) & (clean_data['Jet_0_eta'] < 2)]['PuppiMET_pt'])
axs[2].set_title('Jet_0_eta 2 to 4 vs PuppiMET_pt')
axs[2].set_xlabel('Jet_0_eta')
axs[2].set_ylabel('PuppiMET_pt')

# Plot for eta range 2 to 4 
axs[3].scatter(clean_data[(clean_data['Jet_0_eta'] > 2) & (clean_data['Jet_0_eta'] < 4)]['Jet_0_eta'],
               clean_data[(clean_data['Jet_0_eta'] > 2) & (clean_data['Jet_0_eta'] < 4)]['PuppiMET_pt'])
axs[3].set_title('Jet_0_eta 2 to 4 vs PuppiMET_pt')
axs[3].set_xlabel('Jet_0_eta')
axs[3].set_ylabel('PuppiMET_pt')

# Plot for eta range 4 to 5 
axs[4].scatter(clean_data[(clean_data['Jet_0_eta'] > 4) & (clean_data['Jet_0_eta'] < 5)]['Jet_0_eta'],
               clean_data[(clean_data['Jet_0_eta'] > 4) & (clean_data['Jet_0_eta'] < 5)]['PuppiMET_pt'])
axs[4].set_title('Jet_0_eta 4 to 5 vs PuppiMET_pt')
axs[4].set_xlabel('Jet_0_eta')
axs[4].set_ylabel('PuppiMET_pt')

#plot for eta range -5 to -4
axs[5].scatter(clean_data[(clean_data['Jet_0_eta'] > -5) & (clean_data['Jet_0_eta'] < -4)]['Jet_0_eta'],
               clean_data[(clean_data['Jet_0_eta'] > -5) & (clean_data['Jet_0_eta'] < -4)]['PuppiMET_pt'])
axs[5].set_title('Jet_0_eta -5 to -4 vs PuppiMET_pt')
axs[5].set_xlabel('Jet_0_eta')
axs[5].set_ylabel('PuppiMET_pt')



# Adjust layout for clarity
plt.tight_layout()
plt.show()

# %%
# Calculate Pearson correlation
correlation = clean_data['Jet_0_eta'].corr(clean_data['PuppiMET_pt'])
print("Pearson Correlation between Jet_0_eta and PuppiMET_pt:", correlation)
# Out:
# Pearson Correlation between Jet_0_eta and PuppiMET_pt: 0.1750617310186723

# %%
# Bin Jet_0_eta and create a new column with categories
bins = [-4, -2, 2, 4]
labels = ['-4 to -2', '-2 to 2', '2 to 4']
clean_data['Jet_0_eta_binned'] = pd.cut(clean_data['Jet_0_eta'], bins=bins, labels=labels)

# Plot with the binned data
sns.boxplot(x='Jet_0_eta_binned', y='PuppiMET_pt', data=clean_data)
plt.xlabel('Binned Jet_0_eta')
plt.ylabel('PuppiMET_pt')
plt.title('Box plot of Binned Jet_0_eta vs PuppiMET_pt')
plt.yscale('log')  # Use a log scale for the y-axis
plt.show()

# %%
sns.violinplot(x='Jet_0_eta_binned', y='PuppiMET_pt', data=clean_data)
plt.xlabel('Binned Jet_0_eta')
plt.ylabel('PuppiMET_pt')
plt.title('Violin plot of Binned Jet_0_eta vs PuppiMET_pt')
plt.show()

# %%
clean_data
# Out:
#          Jet_0_eta  Jet_0_phi  Jet_0_pt  Jet_1_eta  Jet_1_phi  Jet_1_pt  \
# 0         1.609619   2.218262      65.0   1.087402   0.043503      25.5
# 1         3.741211   2.044434      56.0   2.262207   1.435547      41.5
# 2         3.219238   2.305664      58.0   2.392578   0.478516      34.0
# 3        -0.217499   3.001465      27.0  -1.435547  -0.671631      23.0
# 4         1.609619   2.479492      40.5   1.087402  -0.845703      27.0
# ...            ...        ...       ...        ...        ...       ...
# 3145852   2.740723   2.218262      34.5   0.217499   0.478516      24.0
# 3145853   0.304504   2.740723      75.0  -2.000977  -0.758667      17.0
# 3145854  -0.043503  -1.106689     233.0  -3.219238  -2.672852      21.5
# 3145855   1.261475   2.392578      97.0   0.652466   0.652466      39.0
# 3145856   1.696533   1.696533      24.5   1.174561   0.565552      22.5
#
#          Jet_2_eta  Jet_2_phi  Jet_2_pt  Jet_3_eta  Jet_3_phi  Jet_3_pt  \
# ...

# %% [markdown]
# #### looks like we need to do some sort of feature engineering for eta's

# %%
clean_data = full_data[full_data['Jet_0_pt'] < 1000]

# %%
clean_data
# Out:
#          Jet_0_eta  Jet_0_phi  Jet_0_pt  Jet_1_eta  Jet_1_phi  Jet_1_pt  \
# 0         1.609619   2.218262      65.0   1.087402   0.043503      25.5
# 1         3.741211   2.044434      56.0   2.262207   1.435547      41.5
# 2         3.219238   2.305664      58.0   2.392578   0.478516      34.0
# 3        -0.217499   3.001465      27.0  -1.435547  -0.671631      23.0
# 4         1.609619   2.479492      40.5   1.087402  -0.845703      27.0
# ...            ...        ...       ...        ...        ...       ...
# 3145852   2.740723   2.218262      34.5   0.217499   0.478516      24.0
# 3145853   0.304504   2.740723      75.0  -2.000977  -0.758667      17.0
# 3145854  -0.043503  -1.106689     233.0  -3.219238  -2.672852      21.5
# 3145855   1.261475   2.392578      97.0   0.652466   0.652466      39.0
# 3145856   1.696533   1.696533      24.5   1.174561   0.565552      22.5
#
#          Jet_2_eta  Jet_2_phi  Jet_2_pt  Jet_3_eta  Jet_3_phi  Jet_3_pt  \
# ...

# %%
#check how many unique are there in Jet_1_eta
clean_data['Jet_1_eta'].nunique()
# Out:
# 81

# %%
plt.hist(clean_data['Jet_0_eta'], bins=50)  # Try different bin counts
plt.xlabel('Jet_0_eta')
plt.ylabel('Frequency')
plt.title('Distribution of Jet_0_eta')
plt.show()

# %% [markdown]
# #### Visualize the clean data

# %%
#plot every column vs PuppiMET_Pt column
for column in clean_data.columns:
    plt.scatter(clean_data[column], clean_data['PuppiMET_pt'])
    plt.ylabel('PuppiMET_Pt')
    plt.xlabel(column)
    plt.title(column + ' vs PuppiMET_Pt')
    plt.show()

# %%
#remove the rows with PuppiMET_pt > 1750
clean_data = clean_data[clean_data['PuppiMET_pt']<1750]

# %%
clean_data
# Out:
#          Jet_0_eta  Jet_0_phi  Jet_0_pt  Jet_1_eta  Jet_1_phi  Jet_1_pt  \
# 0         1.609619   2.218262      65.0   1.087402   0.043503      25.5
# 1         3.741211   2.044434      56.0   2.262207   1.435547      41.5
# 2         3.219238   2.305664      58.0   2.392578   0.478516      34.0
# 3        -0.217499   3.001465      27.0  -1.435547  -0.671631      23.0
# 4         1.609619   2.479492      40.5   1.087402  -0.845703      27.0
# ...            ...        ...       ...        ...        ...       ...
# 3145852   2.740723   2.218262      34.5   0.217499   0.478516      24.0
# 3145853   0.304504   2.740723      75.0  -2.000977  -0.758667      17.0
# 3145854  -0.043503  -1.106689     233.0  -3.219238  -2.672852      21.5
# 3145855   1.261475   2.392578      97.0   0.652466   0.652466      39.0
# 3145856   1.696533   1.696533      24.5   1.174561   0.565552      22.5
#
#          Jet_2_eta  Jet_2_phi  Jet_2_pt  Jet_3_eta  Jet_3_phi  Jet_3_pt  \
# ...

# %%
clean_data.to_csv(path+'clean_data.txt')

# %%
X = clean_data.drop(columns='PuppiMET_pt')

# %%
X
# Out:
#          Jet_0_eta  Jet_0_phi  Jet_0_pt  Jet_1_eta  Jet_1_phi  Jet_1_pt  \
# 0         1.609619   2.218262      65.0   1.087402   0.043503      25.5
# 1         3.741211   2.044434      56.0   2.262207   1.435547      41.5
# 2         3.219238   2.305664      58.0   2.392578   0.478516      34.0
# 3        -0.217499   3.001465      27.0  -1.435547  -0.671631      23.0
# 4         1.609619   2.479492      40.5   1.087402  -0.845703      27.0
# ...            ...        ...       ...        ...        ...       ...
# 3145852   2.740723   2.218262      34.5   0.217499   0.478516      24.0
# 3145853   0.304504   2.740723      75.0  -2.000977  -0.758667      17.0
# 3145854  -0.043503  -1.106689     233.0  -3.219238  -2.672852      21.5
# 3145855   1.261475   2.392578      97.0   0.652466   0.652466      39.0
# 3145856   1.696533   1.696533      24.5   1.174561   0.565552      22.5
#
#          Jet_2_eta  Jet_2_phi  Jet_2_pt  Jet_3_eta  Jet_3_phi  Jet_3_pt  \
# ...

# %%
Y = clean_data['PuppiMET_pt']

# %%
Y
# Out:
# 0           48.759895
# 1          104.013786
# 2           59.436253
# 3           10.841270
# 4           62.679337
#               ...
# 3145852     57.547897
# 3145853     80.715759
# 3145854    244.846283
# 3145855     85.398529
# 3145856     15.334833
# Name: PuppiMET_pt, Length: 3133506, dtype: float64
